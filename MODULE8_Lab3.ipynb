# %% [markdown]
# <a href="https://colab.research.google.com/github/Satya7816/satya-balaji-fmml-lab/blob/main/MODULE8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 14:52:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   413MB/s    in 0.2s
#
# 2023-05-03 14:52:09 (413 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22441  1607.02011v2  We propose a vector-valued regression problem ...  stat
# 26075  1608.05404v1  In [1], we proposed a graph-based formulation ...    cs
# 5685    1202.3323v2  Mirror descent with an entropic regularizer is...    cs
# 35695   1106.5601v2  Dominance-based Rough Set Approach (DRSA), as ...    cs
# 6468   1702.06385v2  Given data over the joint distribution of two ...  stat
# ...             ...                                                ...   ...
# 7572   1802.03713v1  It has been widely observed that many activati...  stat
# 40086  1710.06368v1  A robust and informative local shape descripto...    cs
# 39917  1707.07157v1  This paper proposes a single-shot approach for...    cs
# 36502   1403.1523v2  Alignment-free sequence analysis approaches pr...    cs
# 7692   1802.08768v1  Recent work (Pennington et al, 2017) suggests ...  stat
#
#                                                    title  year  \
# 22441  Kernel Bayesian Inference with Posterior Regul...  2016
# 26075  Multi-Person Tracking by Multicut and Deep Mat...  2016
# 5685   Mirror Descent Meets Fixed Share (and feels no...  2012
# 35695  Class-based Rough Approximation with Dominance...  2011
# 6468   Causal Inference on Multivariate and Mixed-Typ...  2017
# ...                                                  ...   ...
# 7572   Optimizing Neural Networks in the Equivalent C...  2018
# 40086  Deep Spectral Descriptors: Learning the point-...  2017
# 39917  Single-Shot Clothing Category Recognition in F...  2017
# 36502  A Novel Method for Comparative Analysis of DNA...  2014
# 7692   Is Generator Conditioning Causally Related to ...  2018
#
#                                                 keywords
# 22441  [regression, equivalent, reproducing, embeddin...
# 26075  [formulation, hypotheses, introduce, appearanc...
# 5685   [regularizer, logarithmic, dimension, carefull...
# 35695  [dominance, extension, effective, fundamentall...
# 6468   [distribution, variables, inferring, direction...
# ...                                                  ...
# 7572   [activation, functions, rescaling, invariant, ...
# 40086  [informative, descriptor, important, registrat...
# 39917  [recognising, categories, constrained, differe...
# 36502  [alignment, approaches, important, alternative...
# 7692   [controlling, distribution, important, conside...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22441    [regression, equivalent, reproducing, embeddin...
# 26075    [formulation, hypotheses, introduce, appearanc...
# 5685     [regularizer, logarithmic, dimension, carefull...
# 35695    [dominance, extension, effective, fundamentall...
# 6468     [distribution, variables, inferring, direction...
#                                ...
# 13577    [theoretical, covariance, adaptation, evolutio...
# 22068    [diffusion, resonance, tractography, structure...
# 1129     [potential, electroencephalography, controllin...
# 12235    [introduce, detection, sequences, community, i...
# 7414     [optimization, involving, objectives, optimiza...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8955 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="07fb12d7-d97c-4ade-9eb0-b2168705e964" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07fb12d7-d97c-4ade-9eb0-b2168705e964")) {                    Plotly.newPlot(                        "07fb12d7-d97c-4ade-9eb0-b2168705e964",                        [{"x":["consistency","comparable","coincides","formulation","inference","nonlinear","baselines","established","filtering","equivalence","regularization","performance","posterior","framework","extremely","estimator","reproducing","understanding","equivalent","thresholding","optimization","embedding","distribution","theoretical","regression","nonparametric","introduce","occlusion","potentials","experiments","algorithm","benchmark","extensive","achieving","intermediate","hypotheses","applicable","effectiveness","eliminates","different","robustness","appearance","detections","representation","demonstrate","efficient","essentially","improvements","regularizer","including","approaches","generalized","logarithmic","parameters","carefully","dimension","discounted","generalizing","projection","technique","important","classical","definitions","principle","preserving","effective","fundamentally","singleton","investigated","approximations","dominance","extension","approximation","describing","univariate","inferring","description","complexity","information","classification","kolmogorov","computable","variables","multivariate","empirical","particular","theoretic","dependencies","evaluation","approximated","direction","determine","documents","separator","utilizing","historical","strategies","arbitrarily","detection","beginning","substantially","augmentation","developed","outperforms","increased","clustering","annotated","trainable","predictions","uniformly","initialization","supervised","simulated","traditionally","extending","justification","practitioners","randomized","according","initialize","deviations","addresses","perspective","particularly","efficiency","dominates","algorithmic","leveraging","computations","numerical","predictor","algorithms","estimating","improving","providing","predictors","synthetic","performing","computational","statistical","importance","associated","practical","successful","implementations","properties","subproblem","architectures","recommendations","revealing","systematic","separately","ingredients","categories","developers","categorize","similarities","meaningful","distinguish","fundamental","procedures","generalize","experimental","continuously","distributed","streaming","preserves","structure","assumption","efficiently","accurately","biological","topological","furthermore","estimation","induction","objectives","traditional","facilitate","parameter","relational","population","appropriate","underlying","challenging","highlighting","reinforcement","similarity","objective","transition","parametric","propagation","iteration","dimensional","extraction","interpreted","mathematics","interesting","correctly","acoustics"],"y":[61,101,3,82,219,64,56,51,71,29,80,866,48,557,49,37,10,163,45,20,327,97,219,157,100,22,329,35,14,626,829,216,170,72,36,34,55,205,12,735,96,62,16,402,567,424,19,124,21,241,433,75,12,263,18,68,5,17,51,252,343,91,19,56,49,258,7,1,44,39,13,88,123,39,5,19,69,228,677,531,5,8,139,29,137,269,51,52,282,18,58,81,74,3,40,26,93,13,332,7,33,24,207,266,40,141,66,27,70,17,27,181,55,27,39,11,14,25,90,6,6,63,76,75,160,2,54,40,30,93,10,598,62,108,94,14,131,66,289,187,79,118,130,61,32,206,2,118,18,8,30,33,5,70,8,9,38,45,39,112,33,47,378,14,112,17,12,312,77,140,56,39,15,168,216,26,28,155,35,116,33,48,83,113,260,9,116,149,177,27,40,61,42,177,131,13,10,75,28,2],"type":"bar"},{"x":["consistency","comparable","coincides","formulation","inference","nonlinear","baselines","established" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.5264367816091955);'>Detection</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Adjacency</span> <span style=''>and</span> <span style=''>Zoom</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.5264367816091955);'>detection</span> <span style=''>systems</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>an</span> <span style=''>accurate</span> <span style=''>set</span> <span style=''>of</span> <span style=''>region</span> <span style='background-color:rgba(0, 255, 0, 0.4857142857142857);'>proposals</span> <span style=''>Several</span> <span style=''>recent</span> <span style=''>methods</span> <span style=''>use</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.48571428571428565);'>architecture</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>hypothesize</span> <span style='background-color:rgba(0, 255, 0, 0.388235294117647);'>promising</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>locations</span> <span style=''>While</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>they</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>fixed</span> <span style=''>image</span> <span style=''>regions</span> <span style=''>as</span> <span style=''>anchors</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>a</span> <span style=''>search</span> <span style=''>strategy</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adaptively</span> <span style=''>directs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.4252873563218391);'>resources</span> <span style=''>to</span> <span style=''>sub</span> <span style=''>regions</span> <span style=''>likely</span> <span style=''>to</span> <span style=''>contain</span> <span style=''>objects</span> <span style=''>Compared</span> <span style=''>to</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>fixed</span> <span style=''>anchor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>locations</span> <span style=''>our</span> <span style=''>approach</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>adapts</span> <span style=''>to</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.3548387096774193);'>instances</span> <span style=''>are</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>small</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparable</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>accuracy</span> <span style=''>to</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Orthogonal</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Demand</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>in</span> <span style=''>Dynamic</span> <span style=''>Panels</span> <br/><br/><span style=''>There</span> <span style=''>has</span> <span style=''>been</span> <span style=''>growing</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>economists</span> <span style=''>can</span> <span style=''>import</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>tools</span> <span style=''>designed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerate</span> <span style=''>and</span> <span style=''>automate</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>process</span> <span style=''>while</span> <span style=''>still</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>for</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>Focusing</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>Double</span> <span style=''>ML</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>for</span> <span style=''>(1)</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatments</span> <span style=''>that</span> <span style=''>may</span> <span style=''>grow</span> <span style=''>with</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>and</span> <span style=''>(2)</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>panel</span> <span style=''>data</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exogenous</span> <span style=''>errors</span> <span style=''>Our</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>(LD)</span> <span style=''>regime</span> <span style=''>directly</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>work</span> <span style=''>in</span> <span style=''>Chernozhukov</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2016</span> <span style=''>by</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>from</span> <span style=''>a</span> <span style=''>second</span> <span style=''>stage</span> <span style=''>ordinary</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernel</span> <span style=''>Methods</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>Riemannian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Manifolds</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style=''>RBF</span> <span style=''>Kernels</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>with</span> <span style=''>manifold</span> <span style=''>valued</span> <span style=''>data</span> <span style=''>In</span> <span style=''>many</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>problems</span> <span style=''>the</span> <span style=''>data</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>points</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>Riemannian</span> <span style=''>manifold</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>geometry</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>Riemannian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manifolds</span> <span style=''>usual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>yield</span> <span style=''>inferior</span> <span style=''>results</span> <span style=''>on</span> <span style=''>such</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>define</span> <span style=''>Gaussian</span> <span style=''>radial</span> <span style=''>basis</span> <span style=''>function</span> <span style=''>(RBF)</span> <span style=''>based</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>kernels</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manifolds</span> <span style=''>that</span> <span style=''>permit</span> <span style=''>us</span> <span style=''>to</span> <span style=''>embed</span> <span style=''>a</span> <span style=''>given</span> <span style=''>manifold</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>metric</span> <span style=''>in</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.36330935251798563);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.6491228070175439);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>These</span> <span style=''>kernels</span> <span style=''>make</span> <span style=''>it</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>utilize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>linear</span> <span style=''>spaces</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Soft</span> <span style=''>DTW</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differentiable</span> <span style=''>Loss</span> <span style=''>Function</span> <span style=''>for</span> <span style=''>Time</span> <span style=''>Series</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style=''>learning</span> <span style=''>loss</span> <span style=''>between</span> <span style=''>time</span> <span style=''>series</span> <span style=''>building</span> <span style=''>upon</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>celebrated</span> <span style=''>dynamic</span> <span style=''>time</span> <span style=''>warping</span> <span style=''>(DTW)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrepancy</span> <span style=''>Unlike</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>distance</span> <span style=''>DTW</span> <span style=''>can</span> <span style=''>compare</span> <span style=''>time</span> <span style=''>series</span> <span style=''>of</span> <span style=''>variable</span> <span style=''>size</span> <span style=''>and</span> <span style=''>is</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>shifts</span> <span style=''>or</span> <span style=''>dilatations</span> <span style=''>across</span> <span style=''>the</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>To</span> <span style=''>compute</span> <span style=''>DTW</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>solves</span> <span style=''>a</span> <span style=''>minimal</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignment</span> <span style=''>problem</span> <span style=''>between</span> <span style=''>two</span> <span style=''>time</span> <span style=''>series</span> <span style=''>using</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>takes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>a</span> <span style=''>smoothed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>DTW</span> <span style=''>called</span> <span style=''>soft</span> <span style=''>DTW</span> <span style=''>that</span> <span style=''>computes</span> <span style=''>the</span> <span style=''>soft</span> <span style=''>minimum</span> <span style=''>of</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignment</span> <span style=''>costs</span> <span style=''>We</span> <span style=''>show</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>that</span> <span style=''>soft</span> <span style=''>DTW</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>and</span> <span style=''>that</span> <span style=''>both</span> <span style=''>its</span> <span style=''>value</span> <span style=''>and</span> <span style=''>gradient</span> <span style=''>can</span> <span style=''>be</span> <span style=''>computed</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>timespace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09532246633593196)
# 	knowledge (0.11622962437987243)
# 	information (0.239900779588944)
# 	experimental (0.1339475549255847)
# 	representation (0.14245216158752658)
# 	segmentation (0.07618710134656272)
# 	detection (0.11764705882352941)
# 	different (0.26045357902197025)
# 	convolutional (0.1215450035435861)
# 	recognition (0.13288447909284196)
#
# Some Statistics words are:
# 	variables (0.13144590495449948)
# 	stochastic (0.13751263902932254)
# 	theoretical (0.14762386248736098)
# 	statistical (0.16430738119312438)
# 	estimation (0.1789686552072801)
# 	algorithm (0.39838220424671383)
# 	distribution (0.18402426693629928)
# 	inference (0.20070778564206268)
# 	dimensional (0.1916076845298281)
# 	regression (0.1916076845298281)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bb2d1fd2-918b-4f12-9c1d-8751055acde1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb2d1fd2-918b-4f12-9c1d-8751055acde1")) {                    Plotly.newPlot(                        "bb2d1fd2-918b-4f12-9c1d-8751055acde1",                        [{"x":["consistency","comparable","coincides","formulation","inference","nonlinear","baselines","established","filtering","equivalence","regularization","performance","posterior","framework","extremely","estimator","reproducing","understanding","equivalent","thresholding","optimization","embedding","distribution","theoretical","regression","nonparametric","introduce","occlusion","potentials","experiments","algorithm","benchmark","extensive","achieving","intermediate","hypotheses","applicable","effectiveness","eliminates","different","robustness","appearance","detections","representation","demonstrate","efficient","essentially","improvements","regularizer","including","approaches","generalized","logarithmic","parameters","carefully","dimension","discounted","generalizing","projection","technique","important","classical","definitions","principle","preserving","effective","fundamentally","singleton","investigated","approximations","dominance","extension","approximation","describing","univariate","inferring","description","complexity","information","classification","kolmogorov","computable","variables","multivariate","empirical","particular","theoretic","dependencies","evaluation","approximated","direction","determine","documents","separator","utilizing","historical","strategies","arbitrarily","detection","beginning","substantially","augmentation","developed","outperforms","increased","clustering","annotated","trainable","predictions","uniformly","initialization","supervised","simulated","traditionally","extending","justification","practitioners","randomized","according","initialize","deviations","addresses","perspective","particularly","efficiency","dominates","algorithmic","leveraging","computations","numerical","predictor","algorithms","estimating","improving","providing","predictors","synthetic","performing","computational","statistical","importance","associated","practical","successful","implementations","properties","subproblem","architectures","recommendations","revealing","systematic","separately","ingredients","categories","developers","categorize","similarities","meaningful","distinguish","fundamental","procedures","generalize","experimental","continuously","distributed","streaming","preserves","structure","assumption","efficiently","accurately","biological","topological","furthermore","estimation","induction","objectives","traditional","facilitate","parameter","relational","population","appropriate","underlying","challenging","highlighting","reinforcement","similarity","objective","transition","parametric","propagation","iteration","dimensional","extraction","interpreted","mathematics","interesting","correctly","acoustics","considered","exceptional","comparing","weaknesses","presented","mechanisms","techniques","technology","characteristic","strengths","comparative","converting","statistically","relatively","recognition","phonological","insurmountable","subadditive","equilibrium","applications","valuations","approximate","implementable","exponential","roughgarden","optimality","inefficient","combinatorial","reduction","perturbed","polynomial","approximately","repeatedly","fractionally","tractability","polynomially","guarantees","literature","simultaneous","unfortunately","computationally","relaxation","smoothness","unfolding","generated","shrinking","averaging","compromising","generates","ensembles","ensembling","individual","production","drastically","translations","cumbersome","dim ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	hermitian
# 	dimensionalities
# 	underestimates
# 	spreading
# 	uncollapsed
# 	heteroskedastic
# 	cumulants
# 	preconditioning
# 	parametrisation
# 	preconditioned
# 	negativity
# 	uncontaminated
# 	quantiles
# 	subtleties
# 	planetary
# 	exoplanet
# 	discriminable
# 	confounders
# 	covariates
# 	abundances
# Some words which never appear in Statistics papers:
# 	mathematics
# 	acoustics
# 	exceptional
# 	phonological
# 	subadditive
# 	valuations
# 	roughgarden
# 	fractionally
# 	interdependency
# 	assembled
# 	sigmoidal
# 	equipment
# 	worldwide
# 	reflections
# 	smartphone
# 	terrestrial
# 	landmarks
# 	monocular
# 	multiplexing
# 	plasticity

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0483158055174518e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
